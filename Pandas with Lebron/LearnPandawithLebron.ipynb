# %%
import pandas as pd

# %%
l = pd.read_excel('Lebron.xlsx')

# %%
l.loc[0:5]
# Out:
#     Season   Age   Tm   Lg Pos     G    GS      MP   FG   FGA  ...    FT%  \
# 0  2003-04  19.0  CLE  NBA  SG  79.0  79.0  3122.0  7.2  17.2  ...  0.754
# 1  2004-05  20.0  CLE  NBA  SF  80.0  80.0  3388.0  8.4  17.9  ...  0.750
# 2  2005-06  21.0  CLE  NBA  SF  79.0  79.0  3361.0  9.4  19.5  ...  0.738
# 3  2006-07  22.0  CLE  NBA  SF  78.0  78.0  3190.0  8.7  18.3  ...  0.698
# 4  2007-08  23.0  CLE  NBA  SF  75.0  74.0  3027.0  9.4  19.5  ...  0.712
# 5  2008-09  24.0  CLE  NBA  SF  81.0  81.0  3054.0  9.3  19.0  ...  0.780
#
#    ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  1.1  3.8  5.0  5.4  1.5  0.7  3.1  1.7  19.1
# 1  1.2  5.1  6.2  6.1  1.9  0.6  2.8  1.6  23.1
# 2  0.8  5.2  6.0  5.6  1.3  0.7  2.8  1.9  26.5
# 3  0.9  5.0  5.9  5.3  1.4  0.6  2.8  1.9  24.1
# 4  1.6  5.5  7.0  6.4  1.6  1.0  3.0  2.0  26.8
# 5  1.2  6.0  7.2  6.9  1.6  1.1  2.8  1.6  27.2
#
# [6 rows x 29 columns]

# %%
l.loc[-1:]
# Out:
#         Season   Age   Tm   Lg  Pos       G      GS       MP    FG   FGA  ...  \
# 0      2003-04  19.0  CLE  NBA   SG    79.0    79.0   3122.0   7.2  17.2  ...
# 1      2004-05  20.0  CLE  NBA   SF    80.0    80.0   3388.0   8.4  17.9  ...
# 2      2005-06  21.0  CLE  NBA   SF    79.0    79.0   3361.0   9.4  19.5  ...
# 3      2006-07  22.0  CLE  NBA   SF    78.0    78.0   3190.0   8.7  18.3  ...
# 4      2007-08  23.0  CLE  NBA   SF    75.0    74.0   3027.0   9.4  19.5  ...
# 5      2008-09  24.0  CLE  NBA   SF    81.0    81.0   3054.0   9.3  19.0  ...
# 6      2009-10  25.0  CLE  NBA   SF    76.0    76.0   2966.0   9.3  18.5  ...
# 7      2010-11  26.0  MIA  NBA   SF    79.0    79.0   3063.0   8.9  17.5  ...
# 8      2011-12  27.0  MIA  NBA   SF    62.0    62.0   2326.0   9.6  18.1  ...
# 9      2012-13  28.0  MIA  NBA   PF    76.0    76.0   2877.0   9.6  16.9  ...
# 10     2013-14  29.0  MIA  NBA   PF    77.0    77.0   2902.0   9.5  16.8  ...
# ...

# %%
l.iloc[:, ::2]
# Out:
#         Season   Tm  Pos      GS    FG    FG%  3PA   2P    2P%  FTA  ORB  TRB  \
# 0      2003-04  CLE   SG    79.0   7.2  0.417  2.5  6.4  0.438  5.3  1.1  5.0
# 1      2004-05  CLE   SF    80.0   8.4  0.472  3.3  7.3  0.499  6.8  1.2  6.2
# 2      2005-06  CLE   SF    79.0   9.4  0.480  4.1  8.0  0.518  8.7  0.8  6.0
# 3      2006-07  CLE   SF    78.0   8.7  0.476  3.5  7.6  0.513  7.9  0.9  5.9
# 4      2007-08  CLE   SF    74.0   9.4  0.484  4.3  8.1  0.531  9.2  1.6  7.0
# 5      2008-09  CLE   SF    81.0   9.3  0.489  4.5  7.7  0.535  9.0  1.2  7.2
# 6      2009-10  CLE   SF    76.0   9.3  0.503  4.7  7.8  0.560  9.4  0.9  6.7
# 7      2010-11  MIA   SF    79.0   8.9  0.510  3.3  7.8  0.552  7.8  0.9  6.9
# 8      2011-12  MIA   SF    62.0   9.6  0.531  2.3  8.8  0.556  7.8  1.5  7.6
# 9      2012-13  MIA   PF    76.0   9.6  0.565  3.2  8.3  0.602  6.7  1.2  7.6
# 10     2013-14  MIA   PF    77.0   9.5  0.567  3.8  8.1  0.622  7.3  1.0  6.6
# ...

# %%
l[l['Tm'] == 'CLE']
# Out:
#         Season   Age   Tm   Lg  Pos      G     GS       MP    FG   FGA  ...  \
# 0      2003-04  19.0  CLE  NBA   SG   79.0   79.0   3122.0   7.2  17.2  ...
# 1      2004-05  20.0  CLE  NBA   SF   80.0   80.0   3388.0   8.4  17.9  ...
# 2      2005-06  21.0  CLE  NBA   SF   79.0   79.0   3361.0   9.4  19.5  ...
# 3      2006-07  22.0  CLE  NBA   SF   78.0   78.0   3190.0   8.7  18.3  ...
# 4      2007-08  23.0  CLE  NBA   SF   75.0   74.0   3027.0   9.4  19.5  ...
# 5      2008-09  24.0  CLE  NBA   SF   81.0   81.0   3054.0   9.3  19.0  ...
# 6      2009-10  25.0  CLE  NBA   SF   76.0   76.0   2966.0   9.3  18.5  ...
# 11     2014-15  30.0  CLE  NBA   SF   69.0   69.0   2493.0   9.0  18.5  ...
# 12     2015-16  31.0  CLE  NBA   SF   76.0   76.0   2709.0   9.8  18.8  ...
# 13     2016-17  32.0  CLE  NBA   SF   74.0   74.0   2794.0   9.5  17.3  ...
# 14     2017-18  33.0  CLE  NBA   PF   82.0   82.0   3026.0  10.2  18.8  ...
# ...

# %%
~(l['Tm'] == 'CLE')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16     True
# 17     True
# 18     True
# 19    False
# 20     True
# 21     True
# Name: Tm, dtype: bool

# %%
l[l['Tm'] !='CLE']
# Out:
#        Season   Age   Tm   Lg  Pos       G      GS       MP    FG   FGA  ...  \
# 7     2010-11  26.0  MIA  NBA   SF    79.0    79.0   3063.0   8.9  17.5  ...
# 8     2011-12  27.0  MIA  NBA   SF    62.0    62.0   2326.0   9.6  18.1  ...
# 9     2012-13  28.0  MIA  NBA   PF    76.0    76.0   2877.0   9.6  16.9  ...
# 10    2013-14  29.0  MIA  NBA   PF    77.0    77.0   2902.0   9.5  16.8  ...
# 15    2018-19  34.0  LAL  NBA   SF    55.0    55.0   1937.0  10.4  20.4  ...
# 16    2019-20  35.0  LAL  NBA   PG    60.0    60.0   2094.0  10.1  20.2  ...
# 17     Career   NaN  NaN  NBA  NaN  1258.0  1257.0  48329.0   9.3  18.4  ...
# 18        NaN   NaN  NaN  NaN  NaN     NaN     NaN      NaN   NaN   NaN  ...
# 20  4 seasons   NaN  MIA  NBA  NaN   294.0   294.0  11168.0   9.4  17.3  ...
# 21  2 seasons   NaN  LAL  NBA  NaN   115.0   115.0   4031.0  10.2  20.3  ...
#
#       FT%  ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS
# 7   0.759  0.9  6.0  6.9   6.5  1.5  0.6  3.3  1.9  24.8
# ...

# %%
l['Tm']
# Out:
# 0     CLE
# 1     CLE
# 2     CLE
# 3     CLE
# 4     CLE
# 5     CLE
# 6     CLE
# 7     MIA
# 8     MIA
# 9     MIA
# 10    MIA
# 11    CLE
# 12    CLE
# 13    CLE
# 14    CLE
# 15    LAL
# 16    LAL
# 17    NaN
# 18    NaN
# 19    CLE
# 20    MIA
# 21    LAL
# Name: Tm, dtype: object

# %%
l.iloc[:, [0,1,2,3]]
# Out:
#         Season   Age   Tm   Lg
# 0      2003-04  19.0  CLE  NBA
# 1      2004-05  20.0  CLE  NBA
# 2      2005-06  21.0  CLE  NBA
# 3      2006-07  22.0  CLE  NBA
# 4      2007-08  23.0  CLE  NBA
# 5      2008-09  24.0  CLE  NBA
# 6      2009-10  25.0  CLE  NBA
# 7      2010-11  26.0  MIA  NBA
# 8      2011-12  27.0  MIA  NBA
# 9      2012-13  28.0  MIA  NBA
# 10     2013-14  29.0  MIA  NBA
# 11     2014-15  30.0  CLE  NBA
# 12     2015-16  31.0  CLE  NBA
# 13     2016-17  32.0  CLE  NBA
# 14     2017-18  33.0  CLE  NBA
# 15     2018-19  34.0  LAL  NBA
# 16     2019-20  35.0  LAL  NBA
# 17      Career   NaN  NaN  NBA
# 18         NaN   NaN  NaN  NaN
# 19  11 seasons   NaN  CLE  NBA
# 20   4 seasons   NaN  MIA  NBA
# 21   2 seasons   NaN  LAL  NBA
