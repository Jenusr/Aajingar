# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from datetime import datetime

# %%
pm18=pd.read_csv('2018.csv')
pm19=pd.read_csv('2019.csv')
pm20=pd.read_csv('2020.csv')

# %%
pm18.shape
# Out:
# (864, 20)

# %%
pm18.head()
# Out:
#          Date Source   Site ID  POC  Daily Mean PM2.5 Concentration     UNITS  \
# 0  01/01/2018    AQS  60590007    1                            51.8  ug/m3 LC
# 1  01/02/2018    AQS  60590007    1                            63.1  ug/m3 LC
# 2  01/03/2018    AQS  60590007    1                            42.9  ug/m3 LC
# 3  01/04/2018    AQS  60590007    1                            28.9  ug/m3 LC
# 4  01/05/2018    AQS  60590007    1                            16.3  ug/m3 LC
#
#    DAILY_AQI_VALUE Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0              141   Anaheim                1             100.0
# 1              155   Anaheim                1             100.0
# 2              119   Anaheim                1             100.0
# 3               86   Anaheim                1             100.0
# 4               60   Anaheim                1             100.0
#
#    AQS_PARAMETER_CODE        AQS_PARAMETER_DESC  CBSA_CODE  \
# 0               88101  PM2.5 - Local Conditions      31080
# 1               88101  PM2.5 - Local Conditions      31080
# 2               88101  PM2.5 - Local Conditions      31080
# 3               88101  PM2.5 - Local Conditions      31080
# 4               88101  PM2.5 - Local Conditions      31080
#
#                             CBSA_NAME  STATE_CODE       STATE  COUNTY_CODE  \
# 0  Los Angeles-Long Beach-Anaheim, CA           6  California           59
# 1  Los Angeles-Long Beach-Anaheim, CA           6  California           59
# 2  Los Angeles-Long Beach-Anaheim, CA           6  California           59
# 3  Los Angeles-Long Beach-Anaheim, CA           6  California           59
# 4  Los Angeles-Long Beach-Anaheim, CA           6  California           59
#
#    COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 0  Orange       33.83062      -117.93845
# 1  Orange       33.83062      -117.93845
# 2  Orange       33.83062      -117.93845
# 3  Orange       33.83062      -117.93845
# 4  Orange       33.83062      -117.93845

# %%
data18=pm18.rename(columns={'Daily Mean PM2.5 Concentration': 'MeanPM25','Site ID':'SiteID'})

# %%
data18.head()
# Out:
#          Date Source    SiteID  POC  MeanPM25     UNITS  DAILY_AQI_VALUE  \
# 0  01/01/2018    AQS  60590007    1      51.8  ug/m3 LC              141
# 1  01/02/2018    AQS  60590007    1      63.1  ug/m3 LC              155
# 2  01/03/2018    AQS  60590007    1      42.9  ug/m3 LC              119
# 3  01/04/2018    AQS  60590007    1      28.9  ug/m3 LC               86
# 4  01/05/2018    AQS  60590007    1      16.3  ug/m3 LC               60
#
#   Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  AQS_PARAMETER_CODE  \
# 0   Anaheim                1             100.0               88101
# 1   Anaheim                1             100.0               88101
# 2   Anaheim                1             100.0               88101
# 3   Anaheim                1             100.0               88101
# 4   Anaheim                1             100.0               88101
#
#          AQS_PARAMETER_DESC  CBSA_CODE                           CBSA_NAME  \
# 0  PM2.5 - Local Conditions      31080  Los Angeles-Long Beach-Anaheim, CA
# 1  PM2.5 - Local Conditions      31080  Los Angeles-Long Beach-Anaheim, CA
# 2  PM2.5 - Local Conditions      31080  Los Angeles-Long Beach-Anaheim, CA
# 3  PM2.5 - Local Conditions      31080  Los Angeles-Long Beach-Anaheim, CA
# 4  PM2.5 - Local Conditions      31080  Los Angeles-Long Beach-Anaheim, CA
#
#    STATE_CODE       STATE  COUNTY_CODE  COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 0           6  California           59  Orange       33.83062      -117.93845
# 1           6  California           59  Orange       33.83062      -117.93845
# 2           6  California           59  Orange       33.83062      -117.93845
# 3           6  California           59  Orange       33.83062      -117.93845
# 4           6  California           59  Orange       33.83062      -117.93845

# %%
data18['Date']=pd.to_datetime(data18['Date'], infer_datetime_format=True)
indexed18= data18.set_index(['Date'])

# %%
#indexed18=indexed18[['Date','MeanPM25']]
#pm19=pm19[['Date','Daily Mean PM2.5 Concentration']]
#pm20=pm20[['Date','Daily Mean PM2.5 Concentration']]

# %%
#pm18 = pm18.set_index('Date')
#pm19 = pm19.set_index('Date')
#pm20 = pm20.set_index('Date')

# %%
#plot graph
plt.xlabel("Date")
plt.ylabel("pm25")
plt.plot(indexed18)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-30741665b478> in <module>
#       2 plt.xlabel("Date")
#       3 plt.ylabel("pm25")
# ----> 4 plt.plot(indexed18)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     337             self.axes.xaxis.update_units(x)
#     338         if self.axes.yaxis is not None:
# --> 339             self.axes.yaxis.update_units(y)
#     340
#     341         if x.shape[0] != y.shape[0]:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in update_units(self, data)
#    1514         neednew = self.converter != converter
#    1515         self.converter = converter
# -> 1516         default = self.converter.default_units(data, self)
#    1517         if default is not None and self.units is None:
#    1518             self.set_units(default)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/category.py in default_units(data, axis)
#     105         # the conversion call stack is default_units -> axis_info -> convert
#     106         if axis.units is None:
# --> 107             axis.set_units(UnitData(data))
#     108         else:
#     109             axis.units.update(data)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/category.py in __init__(self, data)
#     173         self._counter = itertools.count()
#     174         if data is not None:
# --> 175             self.update(data)
#     176
#     177     @staticmethod
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/category.py in update(self, data)
#     208         # check if convertible to number:
#     209         convertible = True
# --> 210         for val in OrderedDict.fromkeys(data):
#     211             # OrderedDict just iterates over unique values in data.
#     212             cbook._check_isinstance((str, bytes), value=val)
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
#pm18.rename(columns={'Daily Mean PM2.5 Concentration': 'MeanPM25'})
#pm19.rename(columns={'Daily Mean PM2.5 Concentration': 'MeanPM25'})
#pm20.rename(columns={'Daily Mean PM2.5 Concentration': 'MeanPM25'})

# %%
#determining rolling statistics
rolmean = pm18.rolling(window=365).mean()
rolstd = pm18.rolling(window=265).std()
print(rolmean, rolstd)
